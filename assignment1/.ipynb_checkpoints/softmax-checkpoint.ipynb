# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random 
import numpy as np
from cs231n.data_utils import load_CIFAR10 #note this is a function that loads our CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1)) #the -1 allows it to automatically detect the shape and makes it fit
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image #subtracts the mean for each feature on each sample 
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))]) #new column of ones 
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000L, 3073L)
# Train labels shape:  (49000L,)
# Validation data shape:  (1000L, 3073L)
# Validation labels shape:  (1000L,)
# Test data shape:  (1000L, 3073L)
# Test labels shape:  (1000L,)
# dev data shape:  (500L, 3073L)
# dev labels shape:  (500L,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.329398
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** 10 classes, the original weight distribution is close to zero for everything, so we would find the probability for each class to be about the same.

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: -1.150191 analytic: -1.150191, relative error: 3.723750e-08
# numerical: -1.365973 analytic: -1.365973, relative error: 2.935870e-08
# numerical: 1.658127 analytic: 1.658127, relative error: 2.588997e-08
# numerical: 0.284569 analytic: 0.284569, relative error: 1.739092e-08
# numerical: 0.920816 analytic: 0.920816, relative error: 3.167409e-08
# numerical: 0.526881 analytic: 0.526881, relative error: 3.647724e-08
# numerical: -1.332786 analytic: -1.332786, relative error: 1.045481e-08
# numerical: 1.896903 analytic: 1.896902, relative error: 5.647894e-08
# numerical: 3.829413 analytic: 3.829413, relative error: 1.124529e-08
# numerical: -1.949784 analytic: -1.949784, relative error: 6.156238e-09
# numerical: -1.264909 analytic: -1.264909, relative error: 1.796238e-08
# numerical: -0.245884 analytic: -0.245884, relative error: 1.365315e-09
# numerical: 2.145197 analytic: 2.145197, relative error: 2.671528e-08
# numerical: -0.519438 analytic: -0.519438, relative error: 4.970365e-08
# numerical: 3.485239 analytic: 3.485239, relative error: 9.988613e-09
# numerical: -0.912831 analytic: -0.912831, relative error: 1.688968e-08
# numerical: 5.607187 analytic: 5.607187, relative error: 3.787928e-09
# numerical: -1.134845 analytic: -1.134845, relative error: 4.230778e-09
# numerical: 2.530940 analytic: 2.530940, relative error: 1.765563e-08
# numerical: 0.157170 analytic: 0.157170, relative error: 5.063666e-07

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.329398e+00 computed in 0.065000s
# vectorized loss: 2.329398e+00 computed in 0.002000s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = np.logspace(-10, 10, 10)
regularization_strengths = np.logspace(-3, 6, 10)

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
for alpha in learning_rates:
    for reg in regularization_strengths:
        clf = Softmax()
        loss_hist = clf.train(X_train, y_train, learning_rate=alpha, reg=reg,
                    num_iters=500, verbose=True)
        
        y_train_pred = clf.predict(X_train)
        y_val_pred = clf.predict(X_val)
        
        train_acc = np.mean(y_train_pred == y_train)
        val_acc = np.mean(y_val_pred == y_val)
        
        results[(alpha,reg)] = (train_acc, val_acc)
        
        if val_acc > best_val:
            best_val = val_acc
            best_softmax = clf

################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 500: loss 6.889629
# iteration 100 / 500: loss 6.082912
# iteration 200 / 500: loss 6.347233
# iteration 300 / 500: loss 5.701205
# iteration 400 / 500: loss 6.095812
# iteration 0 / 500: loss 5.512265
# iteration 100 / 500: loss 5.196234
# iteration 200 / 500: loss 5.170881
# iteration 300 / 500: loss 5.137096
# iteration 400 / 500: loss 5.350569
# iteration 0 / 500: loss 6.270886
# iteration 100 / 500: loss 6.217002
# iteration 200 / 500: loss 6.152941
# iteration 300 / 500: loss 6.331812
# iteration 400 / 500: loss 6.202834
# iteration 0 / 500: loss 5.229249
# iteration 100 / 500: loss 5.066510
# iteration 200 / 500: loss 5.525795
# iteration 300 / 500: loss 5.569295
# iteration 400 / 500: loss 5.435206
# iteration 0 / 500: loss 6.295942
# iteration 100 / 500: loss 6.336653
# iteration 200 / 500: loss 6.453441
# iteration 300 / 500: loss 6.167218
# iteration 400 / 500: loss 6.786488
# iteration 0 / 500: loss 7.350641
# iteration 100 / 500: loss 7.972326
# iteration 200 / 500: loss 6.974929
# iteration 300 / 500: loss 7.106382
# iteration 400 / 500: loss 6.938573
# iteration 0 / 500: loss 20.526698
# iteration 100 / 500: loss 20.859020
# iteration 200 / 500: loss 20.852791
# iteration 300 / 500: loss 20.242819
# iteration 400 / 500: loss 20.607234
# iteration 0 / 500: loss 157.216967
# iteration 100 / 500: loss 156.891974
# iteration 200 / 500: loss 156.881865
# iteration 300 / 500: loss 156.904998
# iteration 400 / 500: loss 156.809906
# iteration 0 / 500: loss 1545.056829
# iteration 100 / 500: loss 1541.852806
# iteration 200 / 500: loss 1538.684435
# iteration 300 / 500: loss 1535.860540
# iteration 400 / 500: loss 1533.433509
# iteration 0 / 500: loss 15501.638688
# iteration 100 / 500: loss 15194.536611
# iteration 200 / 500: loss 14893.432225
# iteration 300 / 500: loss 14598.689903
# iteration 400 / 500: loss 14308.970225
# iteration 0 / 500: loss 5.527310
# iteration 100 / 500: loss 5.702398
# iteration 200 / 500: loss 5.360241
# iteration 300 / 500: loss 4.793806
# iteration 400 / 500: loss 4.516716
# iteration 0 / 500: loss 4.740319
# iteration 100 / 500: loss 4.681438
# iteration 200 / 500: loss 4.175075
# iteration 300 / 500: loss 3.747924
# iteration 400 / 500: loss 4.232309
# iteration 0 / 500: loss 4.898790
# iteration 100 / 500: loss 4.667185
# iteration 200 / 500: loss 4.399994
# iteration 300 / 500: loss 4.198018
# iteration 400 / 500: loss 4.658093
# iteration 0 / 500: loss 6.683066
# iteration 100 / 500: loss 5.608484
# iteration 200 / 500: loss 5.178073
# iteration 300 / 500: loss 4.822456
# iteration 400 / 500: loss 4.318263
# iteration 0 / 500: loss 5.587302
# iteration 100 / 500: loss 5.402549
# iteration 200 / 500: loss 5.042675
# iteration 300 / 500: loss 4.780651
# iteration 400 / 500: loss 4.989745
# iteration 0 / 500: loss 6.463775
# iteration 100 / 500: loss 6.258471
# iteration 200 / 500: loss 5.735025
# iteration 300 / 500: loss 5.544808
# iteration 400 / 500: loss 5.767734
# iteration 0 / 500: loss 21.694937
# iteration 100 / 500: loss 21.020907
# iteration 200 / 500: loss 20.186755
# iteration 300 / 500: loss 20.046727
# iteration 400 / 500: loss 19.406286
# iteration 0 / 500: loss 159.205179
# iteration 100 / 500: loss 153.687657
# iteration 200 / 500: loss 148.383109
# iteration 300 / 500: loss 143.155150
# iteration 400 / 500: loss 138.342329
# iteration 0 / 500: loss 1550.977677
# iteration 100 / 500: loss 1110.804823
# iteration 200 / 500: loss 795.563232
# iteration 300 / 500: loss 569.985808
# iteration 400 / 500: loss 408.384026
# iteration 0 / 500: loss 15473.995073
# iteration 100 / 500: loss 536.970646
# iteration 200 / 500: loss 20.736335
# iteration 300 / 500: loss 2.888310
# iteration 400 / 500: loss 2.281550
# iteration 0 / 500: loss 5.558658
# iteration 100 / 500: loss 2.327673
# iteration 200 / 500: loss 2.198811
# iteration 300 / 500: loss 1.989714
# iteration 400 / 500: loss 2.088233
# iteration 0 / 500: loss 5.780003
# iteration 100 / 500: loss 2.639758
# iteration 200 / 500: loss 2.039238
# iteration 300 / 500: loss 2.177960
# iteration 400 / 500: loss 2.051479
# iteration 0 / 500: loss 5.590410
# iteration 100 / 500: loss 2.224925
# iteration 200 / 500: loss 2.208483
# iteration 300 / 500: loss 1.978187
# iteration 400 / 500: loss 2.173426
# iteration 0 / 500: loss 6.409906
# iteration 100 / 500: loss 2.308899
# iteration 200 / 500: loss 2.124989
# iteration 300 / 500: loss 2.258894
# iteration 400 / 500: loss 1.847253
# iteration 0 / 500: loss 4.631444
# iteration 100 / 500: loss 2.457297
# iteration 200 / 500: loss 2.353906
# iteration 300 / 500: loss 2.117289
# iteration 400 / 500: loss 2.172897
# iteration 0 / 500: loss 7.789357
# iteration 100 / 500: loss 3.876420
# iteration 200 / 500: loss 3.369386
# iteration 300 / 500: loss 3.213961
# iteration 400 / 500: loss 3.170128
# iteration 0 / 500: loss 21.381633
# iteration 100 / 500: loss 10.868126
# iteration 200 / 500: loss 6.820231
# iteration 300 / 500: loss 4.745537
# iteration 400 / 500: loss 3.393851
# iteration 0 / 500: loss 159.766200
# iteration 100 / 500: loss 2.528074
# iteration 200 / 500: loss 1.944601
# iteration 300 / 500: loss 1.994446
# iteration 400 / 500: loss 1.975616
# iteration 0 / 500: loss 1538.492410
# iteration 100 / 500: loss 2.220003
# iteration 200 / 500: loss 2.228991
# iteration 300 / 500: loss 2.321119
# iteration 400 / 500: loss 2.169577
# iteration 0 / 500: loss 15407.043062
# cs231n\classifiers\softmax.py:110: RuntimeWarning: divide by zero encountered in log
#   loss = np.sum(-np.log(corr_class))
# iteration 100 / 500: loss inf
# iteration 200 / 500: loss inf
# iteration 300 / 500: loss inf
# iteration 400 / 500: loss inf
# iteration 0 / 500: loss 6.024757
# iteration 100 / 500: loss inf
# iteration 200 / 500: loss inf
# iteration 300 / 500: loss inf
# iteration 400 / 500: loss inf
# iteration 0 / 500: loss 6.115235
# iteration 100 / 500: loss 108.677343
# iteration 200 / 500: loss inf
# iteration 300 / 500: loss inf
# iteration 400 / 500: loss inf
# iteration 0 / 500: loss 6.213575
# iteration 100 / 500: loss inf
# iteration 200 / 500: loss inf
# iteration 300 / 500: loss inf
# iteration 400 / 500: loss inf
# iteration 0 / 500: loss 4.834507
# iteration 100 / 500: loss 104.766316
# iteration 200 / 500: loss inf
# iteration 300 / 500: loss inf
# iteration 400 / 500: loss inf
# iteration 0 / 500: loss 5.884200
# iteration 100 / 500: loss 111.968853
# iteration 200 / 500: loss inf
# iteration 300 / 500: loss 107.526911
# iteration 400 / 500: loss inf
# iteration 0 / 500: loss 7.548867
# iteration 100 / 500: loss inf
# iteration 200 / 500: loss inf
# iteration 300 / 500: loss inf
# iteration 400 / 500: loss inf
# iteration 0 / 500: loss 21.704723
# iteration 100 / 500: loss inf
# iteration 200 / 500: loss inf
# iteration 300 / 500: loss inf
# iteration 400 / 500: loss inf
# iteration 0 / 500: loss 157.276791
# iteration 100 / 500: loss inf
# iteration 200 / 500: loss inf
# cs231n\classifiers\softmax.py:121: RuntimeWarning: overflow encountered in double_scalars
#   loss += 0.5* reg * np.sum(W * W)
# cs231n\classifiers\softmax.py:121: RuntimeWarning: overflow encountered in multiply
#   loss += 0.5* reg * np.sum(W * W)
# iteration 300 / 500: loss inf
# iteration 400 / 500: loss inf
# iteration 0 / 500: loss 1533.299220
# iteration 100 / 500: loss inf
# cs231n\classifiers\softmax.py:103: RuntimeWarning: overflow encountered in exp
#   probs = np.exp(scores)
# cs231n\classifiers\softmax.py:101: RuntimeWarning: overflow encountered in subtract
#   scores -= np.max(scores, axis=1)
# cs231n\classifiers\softmax.py:122: RuntimeWarning: overflow encountered in multiply
#   dW += reg * W
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# iteration 0 / 500: loss 15315.279049
# iteration 100 / 500: loss inf
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# iteration 0 / 500: loss 5.709403
# iteration 100 / 500: loss inf
# iteration 200 / 500: loss inf
# iteration 300 / 500: loss inf
# iteration 400 / 500: loss inf
# iteration 0 / 500: loss 5.740396
# iteration 100 / 500: loss inf
# iteration 200 / 500: loss inf
# iteration 300 / 500: loss inf
# iteration 400 / 500: loss inf
# iteration 0 / 500: loss 5.856170
# iteration 100 / 500: loss inf
# iteration 200 / 500: loss inf
# iteration 300 / 500: loss inf
# iteration 400 / 500: loss inf
# iteration 0 / 500: loss 5.311235
# iteration 100 / 500: loss inf
# iteration 200 / 500: loss inf
# iteration 300 / 500: loss inf
# iteration 400 / 500: loss inf
# iteration 0 / 500: loss 5.262109
# iteration 100 / 500: loss inf
# iteration 200 / 500: loss inf
# iteration 300 / 500: loss inf
# iteration 400 / 500: loss inf
# iteration 0 / 500: loss 7.256431
# iteration 100 / 500: loss inf
# iteration 200 / 500: loss inf
# iteration 300 / 500: loss inf
# cs231n\classifiers\softmax.py:101: RuntimeWarning: invalid value encountered in subtract
#   scores -= np.max(scores, axis=1)
# iteration 400 / 500: loss nan
# iteration 0 / 500: loss 19.830421
# iteration 100 / 500: loss inf
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# iteration 0 / 500: loss 159.885571
# iteration 100 / 500: loss inf
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# iteration 0 / 500: loss 1549.055688
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# iteration 0 / 500: loss 15384.690912
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# iteration 0 / 500: loss 5.962600
# iteration 100 / 500: loss inf
# iteration 200 / 500: loss inf
# iteration 300 / 500: loss inf
# iteration 400 / 500: loss inf
# iteration 0 / 500: loss 5.826398
# iteration 100 / 500: loss inf
# iteration 200 / 500: loss inf
# iteration 300 / 500: loss inf
# iteration 400 / 500: loss inf
# iteration 0 / 500: loss 5.777509
# iteration 100 / 500: loss inf
# iteration 200 / 500: loss inf
# iteration 300 / 500: loss inf
# iteration 400 / 500: loss inf
# iteration 0 / 500: loss 6.585021
# iteration 100 / 500: loss inf
# iteration 200 / 500: loss inf
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# iteration 0 / 500: loss 6.459657
# iteration 100 / 500: loss inf
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# iteration 0 / 500: loss 8.279254
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# iteration 0 / 500: loss 20.851674
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# iteration 0 / 500: loss 157.613220
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# iteration 0 / 500: loss 1545.610119
# cs231n\classifiers\linear_classifier.py:72: RuntimeWarning: overflow encountered in multiply
#   self.W += -learning_rate * grad
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# iteration 0 / 500: loss 15250.731411
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# iteration 0 / 500: loss 5.158582
# iteration 100 / 500: loss inf
# iteration 200 / 500: loss inf
# iteration 300 / 500: loss inf
# iteration 400 / 500: loss inf
# iteration 0 / 500: loss 6.438320
# iteration 100 / 500: loss inf
# iteration 200 / 500: loss inf
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# iteration 0 / 500: loss 5.257212
# iteration 100 / 500: loss inf
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# iteration 0 / 500: loss 5.147823
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# lr 1.000000e-10 reg 1.000000e+01 train accuracy: 0.114633 val accuracy: 0.108000
# lr 1.000000e-10 reg 1.000000e+02 train accuracy: 0.131939 val accuracy: 0.153000
# lr 1.000000e-10 reg 1.000000e+03 train accuracy: 0.104878 val accuracy: 0.117000
# lr 1.000000e-10 reg 1.000000e+04 train accuracy: 0.124878 val accuracy: 0.135000
# lr 1.000000e-10 reg 1.000000e+05 train accuracy: 0.104245 val accuracy: 0.107000
# lr 1.000000e-10 reg 1.000000e+06 train accuracy: 0.122510 val accuracy: 0.111000
# lr 1.668101e-08 reg 1.000000e-03 train accuracy: 0.128980 val accuracy: 0.130000
# lr 1.668101e-08 reg 1.000000e-02 train accuracy: 0.157612 val accuracy: 0.154000
# lr 1.668101e-08 reg 1.000000e-01 train accuracy: 0.147857 val accuracy: 0.141000
# lr 1.668101e-08 reg 1.000000e+00 train accuracy: 0.126776 val accuracy: 0.133000
# lr 1.668101e-08 reg 1.000000e+01 train accuracy: 0.155449 val accuracy: 0.163000
# lr 1.668101e-08 reg 1.000000e+02 train accuracy: 0.139633 val accuracy: 0.157000
# lr 1.668101e-08 reg 1.000000e+03 train accuracy: 0.120694 val accuracy: 0.103000
# lr 1.668101e-08 reg 1.000000e+04 train accuracy: 0.143245 val accuracy: 0.155000
# lr 1.668101e-08 reg 1.000000e+05 train accuracy: 0.144184 val accuracy: 0.149000
# lr 1.668101e-08 reg 1.000000e+06 train accuracy: 0.254041 val accuracy: 0.269000
# lr 2.782559e-06 reg 1.000000e-03 train accuracy: 0.332633 val accuracy: 0.324000
# lr 2.782559e-06 reg 1.000000e-02 train accuracy: 0.338551 val accuracy: 0.336000
# lr 2.782559e-06 reg 1.000000e-01 train accuracy: 0.334163 val accuracy: 0.311000
# lr 2.782559e-06 reg 1.000000e+00 train accuracy: 0.340347 val accuracy: 0.326000
# lr 2.782559e-06 reg 1.000000e+01 train accuracy: 0.343837 val accuracy: 0.312000
# lr 2.782559e-06 reg 1.000000e+02 train accuracy: 0.349327 val accuracy: 0.360000
# lr 2.782559e-06 reg 1.000000e+03 train accuracy: 0.387020 val accuracy: 0.379000
# lr 2.782559e-06 reg 1.000000e+04 train accuracy: 0.344878 val accuracy: 0.337000
# lr 2.782559e-06 reg 1.000000e+05 train accuracy: 0.280633 val accuracy: 0.278000
# lr 2.782559e-06 reg 1.000000e+06 train accuracy: 0.099980 val accuracy: 0.107000
# lr 4.641589e-04 reg 1.000000e-03 train accuracy: 0.314224 val accuracy: 0.311000
# lr 4.641589e-04 reg 1.000000e-02 train accuracy: 0.235592 val accuracy: 0.260000
# lr 4.641589e-04 reg 1.000000e-01 train accuracy: 0.288551 val accuracy: 0.291000
# lr 4.641589e-04 reg 1.000000e+00 train accuracy: 0.318776 val accuracy: 0.321000
# lr 4.641589e-04 reg 1.000000e+01 train accuracy: 0.216633 val accuracy: 0.201000
# lr 4.641589e-04 reg 1.000000e+02 train accuracy: 0.239082 val accuracy: 0.245000
# lr 4.641589e-04 reg 1.000000e+03 train accuracy: 0.111000 val accuracy: 0.100000
# lr 4.641589e-04 reg 1.000000e+04 train accuracy: 0.047286 val accuracy: 0.049000
# lr 4.641589e-04 reg 1.000000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.641589e-04 reg 1.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.742637e-02 reg 1.000000e-03 train accuracy: 0.294429 val accuracy: 0.274000
# lr 7.742637e-02 reg 1.000000e-02 train accuracy: 0.314204 val accuracy: 0.303000
# lr 7.742637e-02 reg 1.000000e-01 train accuracy: 0.247796 val accuracy: 0.249000
# lr 7.742637e-02 reg 1.000000e+00 train accuracy: 0.216408 val accuracy: 0.199000
# lr 7.742637e-02 reg 1.000000e+01 train accuracy: 0.114735 val accuracy: 0.106000
# lr 7.742637e-02 reg 1.000000e+02 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.742637e-02 reg 1.000000e+03 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.742637e-02 reg 1.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.742637e-02 reg 1.000000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.742637e-02 reg 1.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.291550e+01 reg 1.000000e-03 train accuracy: 0.214980 val accuracy: 0.216000
# lr 1.291550e+01 reg 1.000000e-02 train accuracy: 0.187245 val accuracy: 0.205000
# lr 1.291550e+01 reg 1.000000e-01 train accuracy: 0.087163 val accuracy: 0.075000
# lr 1.291550e+01 reg 1.000000e+00 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.291550e+01 reg 1.000000e+01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.291550e+01 reg 1.000000e+02 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.291550e+01 reg 1.000000e+03 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.291550e+01 reg 1.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.291550e+01 reg 1.000000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.291550e+01 reg 1.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.154435e+03 reg 1.000000e-03 train accuracy: 0.058245 val accuracy: 0.064000
# lr 2.154435e+03 reg 1.000000e-02 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.154435e+03 reg 1.000000e-01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.154435e+03 reg 1.000000e+00 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.154435e+03 reg 1.000000e+01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.154435e+03 reg 1.000000e+02 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.154435e+03 reg 1.000000e+03 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.154435e+03 reg 1.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.154435e+03 reg 1.000000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.154435e+03 reg 1.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.593814e+05 reg 1.000000e-03 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.593814e+05 reg 1.000000e-02 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.593814e+05 reg 1.000000e-01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.593814e+05 reg 1.000000e+00 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.593814e+05 reg 1.000000e+01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.593814e+05 reg 1.000000e+02 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.593814e+05 reg 1.000000e+03 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.593814e+05 reg 1.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.593814e+05 reg 1.000000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.593814e+05 reg 1.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.994843e+07 reg 1.000000e-03 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.994843e+07 reg 1.000000e-02 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.994843e+07 reg 1.000000e-01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.994843e+07 reg 1.000000e+00 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.994843e+07 reg 1.000000e+01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.994843e+07 reg 1.000000e+02 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.994843e+07 reg 1.000000e+03 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.994843e+07 reg 1.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.994843e+07 reg 1.000000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.994843e+07 reg 1.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+10 reg 1.000000e-03 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+10 reg 1.000000e-02 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+10 reg 1.000000e-01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+10 reg 1.000000e+00 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+10 reg 1.000000e+01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+10 reg 1.000000e+02 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+10 reg 1.000000e+03 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+10 reg 1.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+10 reg 1.000000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+10 reg 1.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# best validation accuracy achieved during cross-validation: 0.379000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.365000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
